# %% [markdown]
# # Netflix Movies & TV Shows Analysis
# ## 1.Exploratory Data Analysis (EDA) Project
#
# **Name:** Samyuktha Jakkula
#
# **Internship:** Pluto Academy AI & ML Internship
#
# **Tools Used:** Python, Pandas, NumPy, Matplotlib, Seaborn

# %% [markdown]
# ## 2. Project Objective
#
# The objective of this project is to analyze the Netflix Movies and TV Shows dataset, identify trends and patterns, visualize key insights, and provide business recommendations based on the findings.

# %% [markdown]
# ##3. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'netflix_titles.csv', '.ipynb_checkpoints', 'drive', 'sample_data']

# %% [markdown]
# ##4. Load Dataset

# %%
import pandas as pd

df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ##5. Dataset Overview

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## **Dataset Summary**
#
# The dataset contains information about Netflix content including title, director, cast, country, release year, ratings, and genres.

# %% [markdown]
# ##6. Data Cleaning Section

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'] = df['director'].fillna('Unknown')

# %%
df['cast'] = df['cast'].fillna('Unknown')

# %%
df['country'] = df['country'].fillna('Unknown')

# %%
df = df.dropna(subset=['rating'])

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ## **Cleaning Decisions**
#
# 1. Missing directors replaced with 'Unknown'
# 2. Missing cast values replaced with 'Unknown'
# 3. Missing country values replaced with 'Unknown'
# 4. Records with missing rating/date/duration removed

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['date_added'] = df['date_added'].str.strip()

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df[['date_added', 'year_added']].head()
# Out:
#   date_added  year_added
# 0 2021-09-25        2021
# 1 2021-09-24        2021
# 2 2021-09-24        2021
# 3 2021-09-24        2021
# 4 2021-09-24        2021

# %%
df['date_added'].head()
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['year_added'] = df['date_added'].dt.year
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'year_added'],
#       dtype='object')

# %%
df[['date_added', 'year_added']].head()
# Out:
#   date_added  year_added
# 0 2021-09-25        2021
# 1 2021-09-24        2021
# 2 2021-09-24        2021
# 3 2021-09-24        2021
# 4 2021-09-24        2021

# %%
df['director'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')

df = df.dropna(subset=['date_added','rating','duration'])

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# year_added      0
# dtype: int64

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df['date_added'].dt.year

# %%
df[['date_added','year_added']].head()
# Out:
#   date_added  year_added
# 0 2021-09-25        2021
# 1 2021-09-24        2021
# 2 2021-09-24        2021
# 3 2021-09-24        2021
# 4 2021-09-24        2021

# %% [markdown]
# 1. The dataset contains information about Netflix Movies and TV Shows.
# 2. It includes title, director, cast, country, release year and ratings.
# 3. Missing values were identified and handled during preprocessing.
# 4. The dataset contains content from multiple countries and genres.
# 5. The data can be used to analyze Netflix content trends and viewing patterns.

# %% [markdown]
# ##**Better EDA Questions**

# %% [markdown]
# ##Question 1: How many Movies and TV Shows are available on Netflix?

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# Movies are more numerous than TV Shows on Netflix.

# %% [markdown]
# ##**Question 2**: Which countries produce the most Netflix content?

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2809
# India              972
# Unknown            829
# United Kingdom     418
# Japan              243
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %% [markdown]
# Observation:
# The United States contributes the highest number of Netflix titles.

# %% [markdown]
# ##Question 3: What are the most common content ratings?

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %% [markdown]
# obs:TV-MA is the most common content rating, indicating a large amount of mature content.

# %% [markdown]
# ##Question 4: Which years had the highest content releases?

# %%
df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
# 2021     592
# 2015     555
# 2014     352
# 2013     286
# 2012     236
# Name: count, dtype: int64

# %% [markdown]
# **Observation**:
#
# Most Netflix titles were released in recent years, showing growth in content production.

# %% [markdown]
# ##Question 5: What are the most popular genres?

# %%
df['listed_in'].value_counts().head(10)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %% [markdown]
# **Observation**:
#
# Drama and International content categories appear frequently in the dataset.

# %% [markdown]
# ##**Visualizations**
# **1.Bar chart**

# %%
df['type'].value_counts().plot(kind='bar')

plt.title('Movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **2. Pie Chart**

# %%
df['type'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title('Content Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# **3. Histogram**

# %%
plt.hist(df['release_year'], bins=20)

plt.title('Release Year Distribution')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **4. Line Chart**

# %%
df['year_added'].value_counts().sort_index().plot(kind='line')

plt.title('Content Added Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **5. Scatter Plot**

# %%
plt.scatter(df.index, df['release_year'])

plt.title('Release Year Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Release Year')
plt.show()

# %% [markdown]
# **6. Heatmap**

# %%
sns.heatmap(df.isnull(), cbar=False)

plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# **Business** **Recommendations**
# ## Recommendations
#
# 1. Increase investment in successful drama content.
#
# 2. Expand production in emerging international markets.
#
# 3. Continue focusing on mature audience content while balancing family-friendly titles.
#
# 4. Analyze high-performing genres for future content planning.
#
# 5. Use country-wise trends to improve regional content recommendations.
